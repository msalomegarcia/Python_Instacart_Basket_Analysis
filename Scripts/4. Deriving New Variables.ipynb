# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\salom\OneDrive\Documentos\11-2025 Instacart Basket Analysis'

# %%
# Import merged pkl dataframe

df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))

# %%
# Created subset of the dataframe for the first one million rows.

df = df_ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 13)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices
# ...

# %%
df.tail()
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 999995   2789027     6474             2                   3
# 999996   2789027     6474             2                   3
# 999997   2789027     6474             2                   3
# 999998   2789027     6474             2                   3
# 999999   2789027     6474             2                   3
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 999995                  8                    30.0        3020
# 999996                  8                    30.0       35823
# 999997                  8                    30.0       27681
# 999998                  8                    30.0        2091
# 999999                  8                    30.0       44199
#
#         add_to_cart_order  reordered  \
# 999995                  7          0
# 999996                  8          0
# 999997                  9          0
# 999998                 10          0
# ...

# %%
# Define price label function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply the function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\salom\AppData\Local\Temp\ipykernel_33044\93659844.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.value_counts('price_range')
# Out:
# price_range
# Mid-range product    673340
# Low-range product    314392
# High range            12268
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 25.0

# %%
# Create conditions using loc function

df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     21865987
# Low-range product     10126321
# High-range product      412551
# Name: count, dtype: int64

# %%
# Print the frequency of the “orders_day_of_week” column

df_ords_prods_merged['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# Create list for busiest day using a for loop

result = []

for value in df_ords_prods_merged['orders_day_of_week']:
  if value == 0:
    result.append('Busiest day')
  elif value == 4:
    result.append('Least busy')
  else:
    result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Create new column to combine with list for busiest day

df_ords_prods_merged['busiest_day']= result

# %%
# Print the frequency of this new column and cross-check it with the frequency of “orders_day_of_week”

df_ords_prods_merged['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# ### Exercise 4.7 Directions

# %% [markdown]
# #### Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# Create new list for busiest days using a for loop

result = []

for value in df_ords_prods_merged['orders_day_of_week']:
  if value == 0:
    result.append('Busiest days')
  elif value == 1:
    result.append('Busiest days')
  elif value == 4:
    result.append('Slowest days')
  elif value == 3:
    result.append('Slowest days')
  else:
    result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
# ...

# %%
# Create new column to combine with list for busiest days

df_ords_prods_merged['busiest_days']= result

# %%
# Print the frequency of this new column and cross-check it with the frequency of “orders_day_of_week”

df_ords_prods_merged['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: count, dtype: int64

# %% [markdown]
# #### In this new column the number of regularly busy days is reduced by more than half, while the busiest and slowest days double. The values sum is accurate.

# %% [markdown]
# #### When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
# Create a temp table to determine the frequency of the “order_hour_of_day” column

orders_frequency = df_ords_prods_merged['order_hour_of_day'].value_counts(dropna=False)

# %%
orders_frequency
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
orders_frequency.describe()
# Out:
# count    2.400000e+01
# mean     1.350202e+06
# std      1.078369e+06
# min      5.128100e+04
# 25%      2.725620e+05
# 50%      1.117230e+06
# 75%      2.556034e+06
# max      2.761760e+06
# Name: count, dtype: float64

# %%
# Create conditions using loc function: 
# Most orders -q4- 10,11,14,15,13,12
# Average orders -q3,q2- 16,9,17,8,18,19,20,7,21,22,23,6
# Fewest orders -q1- 0,1,5,2,4,3

df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] >= 10) & (df_ords_prods_merged['order_hour_of_day'] <= 15), 'busiest_period_of_day'] = 'Most orders'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] >= 6) & (df_ords_prods_merged['order_hour_of_day'] <= 9), 'busiest_period_of_day'] = 'Average orders'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] >= 16) & (df_ords_prods_merged['order_hour_of_day'] <= 23), 'busiest_period_of_day'] = 'Average orders'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] <= 5), 'busiest_period_of_day'] = 'Fewest orders'

# %%
# Print the frequency of this new column

df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Most orders       16128666
# Average orders    15679865
# Fewest orders       596328
# Name: count, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
# Export data to pkl

df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_derived.pkl'))
